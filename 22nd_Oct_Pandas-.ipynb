# %%
import pandas as pd

# %% [raw]
# To install pandas
# !pip install pandas

# %%
pd.__version__
# Out:
# '1.0.1'

# %%
df = pd.read_csv("petrol_consumption.csv")

# %%
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#this is only for windows
df =pd.read_csv("C:\\Users\\Harika\\Python\\petrol_consumption.csv")

# %%
df.head(10) # by default ,top 5 rows
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
# 5        10.0            5342            1333                         0.571
# 6         8.0            5319           11868                         0.451
# 7         8.0            5126            2138                         0.553
# 8         8.0            4447            8577                         0.529
# 9         7.0            4512            8507                         0.552
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# ...

# %%
df.describe()
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
df.info() # tells you how many non null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Petrol_tax                    48 non-null     float64
#  1   Average_income                48 non-null     int64
#  2   Paved_Highways                48 non-null     int64
#  3   Population_Driver_licence(%)  48 non-null     float64
#  4   Petrol_Consumption            48 non-null     int64
# dtypes: float64(2), int64(3)
# memory usage: 2.0 KB

# %%
df.shape # gives you no of rows and col
# Out:
# (48, 5)

# %%
df.columns # returns all the col names
# Out:
# Index(['Petrol_tax', 'Average_income', 'Paved_Highways',
#        'Population_Driver_licence(%)', 'Petrol_Consumption'],
#       dtype='object')

# %%
df.tail() # gives you bottom 5 rows
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 43         7.0            3745            2611                         0.508
# 44         6.0            5215            2302                         0.672
# 45         9.0            4476            3942                         0.571
# 46         7.0            4296            4083                         0.623
# 47         7.0            5002            9794                         0.593
#
#     Petrol_Consumption
# 43                 591
# 44                 782
# 45                 510
# 46                 610
# 47                 524

# %%
df['Petrol_tax']   #data series
# Out:
# 0      9.00
# 1      9.00
# 2      9.00
# 3      7.50
# 4      8.00
# 5     10.00
# 6      8.00
# 7      8.00
# 8      8.00
# 9      7.00
# 10     8.00
# 11     7.50
# 12     7.00
# 13     7.00
# 14     7.00
# 15     7.00
# 16     7.00
# 17     7.00
# 18     7.00
# 19     8.50
# 20     7.00
# 21     8.00
# 22     9.00
# 23     9.00
# 24     8.50
# 25     9.00
# 26     8.00
# 27     7.50
# 28     8.00
# 29     9.00
# 30     7.00
# 31     7.00
# 32     8.00
# 33     7.50
# 34     8.00
# 35     6.58
# 36     5.00
# 37     7.00
# 38     8.50
# 39     7.00
# 40     7.00
# 41     7.00
# 42     7.00
# 43     7.00
# 44     6.00
# 45     9.00
# 46     7.00
# 47     7.00
# Name: Petrol_tax, dtype: float64

# %%
df.Petrol_tax
# Out:
# 0      9.00
# 1      9.00
# 2      9.00
# 3      7.50
# 4      8.00
# 5     10.00
# 6      8.00
# 7      8.00
# 8      8.00
# 9      7.00
# 10     8.00
# 11     7.50
# 12     7.00
# 13     7.00
# 14     7.00
# 15     7.00
# 16     7.00
# 17     7.00
# 18     7.00
# 19     8.50
# 20     7.00
# 21     8.00
# 22     9.00
# 23     9.00
# 24     8.50
# 25     9.00
# 26     8.00
# 27     7.50
# 28     8.00
# 29     9.00
# 30     7.00
# 31     7.00
# 32     8.00
# 33     7.50
# 34     8.00
# 35     6.58
# 36     5.00
# 37     7.00
# 38     8.50
# 39     7.00
# 40     7.00
# 41     7.00
# 42     7.00
# 43     7.00
# 44     6.00
# 45     9.00
# 46     7.00
# 47     7.00
# Name: Petrol_tax, dtype: float64

# %%
df.Petrol_tax.sum()
# Out:
# 368.08

# %%
df.Petrol_tax.min()
# Out:
# 5.0

# %%
df.Petrol_tax.max()
# Out:
# 10.0

# %%
df.Petrol_tax.mean()
# Out:
# 7.668333333333333

# %%
df['new_col1'] = 0

# %%
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption  new_col1
# 0                 541         0
# 1                 524         0
# 2                 561         0
# 3                 414         0
# 4                 410         0

# %%
df['new_Petrol_consumption'] = df.Petrol_Consumption+10

# %%
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption  new_col1  new_Petrol_consumption
# 0                 541         0                     551
# 1                 524         0                     534
# 2                 561         0                     571
# 3                 414         0                     424
# 4                 410         0                     420

# %%
df.drop(columns = ['new_col1'])
# Out:
#     Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.00            3571            1976                         0.525
# 1         9.00            4092            1250                         0.572
# 2         9.00            3865            1586                         0.580
# 3         7.50            4870            2351                         0.529
# 4         8.00            4399             431                         0.544
# 5        10.00            5342            1333                         0.571
# 6         8.00            5319           11868                         0.451
# 7         8.00            5126            2138                         0.553
# 8         8.00            4447            8577                         0.529
# 9         7.00            4512            8507                         0.552
# 10        8.00            4391            5939                         0.530
# ...

# %%
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption  new_col1  new_Petrol_consumption
# 0                 541         0                     551
# 1                 524         0                     534
# 2                 561         0                     571
# 3                 414         0                     424
# 4                 410         0                     420

# %%
df = df.drop(columns = ['new_col1'])

# %%
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption  new_Petrol_consumption
# 0                 541                     551
# 1                 524                     534
# 2                 561                     571
# 3                 414                     424
# 4                 410                     420

# %%
df.loc[:,["Petrol_tax" ,"Average_income"]]
# Out:
#     Petrol_tax  Average_income
# 0         9.00            3571
# 1         9.00            4092
# 2         9.00            3865
# 3         7.50            4870
# 4         8.00            4399
# 5        10.00            5342
# 6         8.00            5319
# 7         8.00            5126
# 8         8.00            4447
# 9         7.00            4512
# 10        8.00            4391
# 11        7.50            5126
# 12        7.00            4817
# 13        7.00            4207
# 14        7.00            4332
# 15        7.00            4318
# 16        7.00            4206
# 17        7.00            3718
# 18        7.00            4716
# 19        8.50            4341
# 20        7.00            4593
# 21        8.00            4983
# 22        9.00            4897
# 23        9.00            4258
# 24        8.50            4574
# 25        9.00            3721
# 26        8.00            3448
# 27        7.50            3846
# 28        8.00            4188
# ...
