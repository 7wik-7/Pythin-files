# %%
str = "hello python !"   # Use of reserved keyword str
str.replace['hello' , 'cat', 0]   # Use of square brackets

# %%
str1 = "Hello Python"
str1.replace("Hello", "Lovely")
str1
# Out:
# 'Lovely Python'

# %%
df2 = df1.loc[(df1.col2 > 100) & (df1.col5 == 'normal')]   
df2.loc[df2.col10] = 'OK'

# %%
df1.loc[(df1.col2 > 100) & (df1.col5 == 'normal'), "col10"] = "OK"

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import sklearn
from sklearn.datasets import load_wine

# %%
import seaborn as sns
sns.set()
fmri = sns.load_dataset("fmri")

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x="timepoint", y="signal", data=fmri, hue='region')

# %%
sns.__version__
# Out:
# '0.11.0'

# %%
sns.histplot(data=fmri.signal)

# %%
sns.distplot(fmri.signal)
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Install a package - 
# pip install <package_name>

# Uninstall a package - 
# pip uninstall <package_name> 

# Upgrade the package 
# pip insall ---upgrade <package_name> 

# Know which packages are installed 
# pip list or pip freeze 

# Know pip package infromation 
# pip show <package_name>

# %%
! pip show pandas
# Out:
# Name: pandas
# Version: 1.1.3
# Summary: Powerful data structures for data analysis, time series, and statistics
# Home-page: https://pandas.pydata.org
# Author: None
# Author-email: None
# License: BSD
# Location: /usr/local/lib/python3.6/dist-packages
# Requires: pytz, python-dateutil, numpy
# Required-by: xarray, vega-datasets, statsmodels, sklearn-pandas, seaborn, pymc3, plotnine, pandas-profiling, pandas-gbq, pandas-datareader, mlxtend, mizani, holoviews, gspread-dataframe, google-colab, fix-yahoo-finance, fbprophet, fastai, cufflinks, cmdstanpy, altair

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
# Subplotting - Plot multiple graphs on same view

plt.figure(figsize=(10, 10))
plt.subplot(2,3,1)               # Syntax - [ROWS, COLS, INDEX_WHERE_TO_PLACE_THIS_PARTICULAR_GRAPH]
plt.plot(fmri.timepoint)

plt.subplot(2,3,3)
sns.histplot(data=fmri.signal)

plt.subplot(2,3,4)
fmri.region.value_counts().plot.bar()

plt.subplot(2,3,6)
fmri.event.value_counts().plot.pie()

plt.show()

# %%
plt.plot(fmri.timepoint)
plt.savefig("timepoint_line_plot.png", dpi=330)

# %%
sns.histplot(data=fmri.signal)
plt.savefig("sns_plot.png")

# %%
#Machine Learning -

# %%
# Traditional Code - We have a input + Equation => Output 
                #    3,2             + Multiply => 6

# Machine Learning - 
                # Input      Output     Eqution 
                #   3,2    - 6          I1 * I2 
                #   1,2    - 2
                #   4,2    - 8

# %%
# ML has 2 phase - 
# 1. Training (Training of a model)
# 2. Prediction

# %%
# Training Phase (I Phase)(Input, Output) -> Model (Equation) // 
# Example - Predict the sales of Q1 2021 in Nov 2020 ???

# REMEMBER - Training data is historical in nature and has already occured.  

# Inputs/Independent Features - are those columns/ feature which heavily impact the sales. 
# Output/Dependent   Features - generated revenue for the last quarters 

# The model tries to learn the pattern between them and find relationships

# %%
#                     -------
# Input + Output --> [ML Algo] --> ML Model
#                     -------
# ML Model - can be understood as relationship between input Vs output that was harvested from trining data. 
# ML Model - is a big math equation

# %%
# ML Model => 3.45*[Marketing Spend] + 17.2*[Growth Products] + 10.3*[New Launch]/13  + ... = Expected Revenue(in $M)

# %%
# Prediction Phase (II Phase) (Input, ML Model) -> Output(expected sales)

# %%
### Data Science, Machine Learning, Deep Learning, Artificial Intellgence  ###
# Data Science            - generate insights from your data
# Machine Learning        - Predict the future (--almost-- done on numerical data)
# Deep Learning           - Image/video/speech/text arr handled by deep learning  
# Artificial Intelligence - End-2-End developed while using DL/ML/Ds or even some rules
