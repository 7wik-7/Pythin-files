# %%
import pandas as pd

# %%
df =pd.read_csv("D://Intellipaat//PYTHON//Datasets/petrol_consumption.csv")

# %%
df.shape
# Out:
# (48, 5)

# %%
df2 = pd.read_csv("D://Intellipaat//PYTHON//Datasets/Dataset_spine.csv")

# %% [markdown]
# df2.shape

# %%
df2.shape
# Out:
# (310, 14)

# %%
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
df.head()
# Out:
#    Petrol_tax  Average_income  Paved_Highways  Population_Driver_licence(%)  \
# 0         9.0            3571            1976                         0.525
# 1         9.0            4092            1250                         0.572
# 2         9.0            3865            1586                         0.580
# 3         7.5            4870            2351                         0.529
# 4         8.0            4399             431                         0.544
#
#    Petrol_Consumption
# 0                 541
# 1                 524
# 2                 561
# 3                 414
# 4                 410

# %%
df2.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6  \
# 0  63.027818  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
#
#        Col7     Col8     Col9     Col10      Col11    Col12 Class_att  \
# 0  0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123  Abnormal
# 1  0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102  Abnormal
# 2  0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221  Abnormal
# 3  0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329  Abnormal
# 4  0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171  Abnormal
#
#                                          Unnamed: 13
# 0                                                NaN
# ...

# %%
df2_col = {
    "Col1" : "pelvic_incidence", 
    "Col2" : "pelvic_tilt",
    "Col3" : "lumbar_lordosis_angle",
    "Col4" : "sacral_slope", 
    "Col5" : "pelvic_radius",
    "Col6" : "degree_spondylolisthesis", 
    "Col7" : "pelvic_slope",
    "Col8" : "direct_tilt",
    "Col9" : "thoracic_slope", 
    "Col10" :"cervical_tilt", 
    "Col11" : "sacrum_angle",
    "Col12" : "scoliosis_slope", 
    "Class_att" : "class",
    "Unnamed:13" : "Remarks"}

# %%
df2.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis',
#        'pelvic_slope', 'direct_tilt', 'thoracic_slope', 'cervical_tilt',
#        'sacrum_angle', 'scoliosis_slope', 'class', 'Unnamed: 13'],
#       dtype='object')

# %%
df2.rename(columns = df2_col)
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0           63.027818    22.552586              39.609117     40.475232
# 1           39.056951    10.060991              25.015378     28.995960
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 4           49.712859     9.652075              28.317406     40.060784
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# ...

# %%
df2.head()
# Out:
#         Col1       Col2       Col3       Col4        Col5       Col6  \
# 0  63.027818  22.552586  39.609117  40.475232   98.672917  -0.254400
# 1  39.056951  10.060991  25.015378  28.995960  114.405425   4.564259
# 2  68.832021  22.218482  50.092194  46.613539  105.985135  -3.530317
# 3  69.297008  24.652878  44.311238  44.644130  101.868495  11.211523
# 4  49.712859   9.652075  28.317406  40.060784  108.168725   7.918501
#
#        Col7     Col8     Col9     Col10      Col11    Col12 Class_att  \
# 0  0.744503  12.5661  14.5386  15.30468 -28.658501  43.5123  Abnormal
# 1  0.415186  12.8874  17.5323  16.78486 -25.530607  16.1102  Abnormal
# 2  0.474889  26.8343  17.4861  16.65897 -29.031888  19.2221  Abnormal
# 3  0.369345  23.5603  12.7074  11.42447 -30.470246  18.8329  Abnormal
# 4  0.543360  35.4940  15.9546   8.87237 -16.378376  24.9171  Abnormal
#
#                                          Unnamed: 13
# 0                                                NaN
# ...

# %%
df2 = df2.rename(columns = df2_col)

# %%
df2.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 0      98.672917                 -0.254400      0.744503      12.5661
# 1     114.405425                  4.564259      0.415186      12.8874
# 2     105.985135                 -3.530317      0.474889      26.8343
# 3     101.868495                 11.211523      0.369345      23.5603
# 4     108.168725                  7.918501      0.543360      35.4940
#
#    thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope     class  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Petrol_tax                    48 non-null     float64
#  1   Average_income                48 non-null     int64
#  2   Paved_Highways                48 non-null     int64
#  3   Population_Driver_licence(%)  48 non-null     float64
#  4   Petrol_Consumption            48 non-null     int64
# dtypes: float64(2), int64(3)
# memory usage: 2.0 KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 310 entries, 0 to 309
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          310 non-null    float64
#  1   pelvic_tilt               310 non-null    float64
#  2   lumbar_lordosis_angle     310 non-null    float64
#  3   sacral_slope              310 non-null    float64
#  4   pelvic_radius             310 non-null    float64
#  5   degree_spondylolisthesis  310 non-null    float64
#  6   pelvic_slope              310 non-null    float64
#  7   direct_tilt               310 non-null    float64
#  8   thoracic_slope            310 non-null    float64
#  9   cervical_tilt             310 non-null    float64
#  10  sacrum_angle              310 non-null    float64
#  11  scoliosis_slope           310 non-null    float64
#  12  class                     310 non-null    object
# ...

# %%
df2.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis',
#        'pelvic_slope', 'direct_tilt', 'thoracic_slope', 'cervical_tilt',
#        'sacrum_angle', 'scoliosis_slope', 'class', 'Unnamed: 13'],
#       dtype='object')

# %%
df3 = df2.drop(columns = "Unnamed: 13" )

# %%
df3.columns
# Out:
# Index(['pelvic_incidence', 'pelvic_tilt', 'lumbar_lordosis_angle',
#        'sacral_slope', 'pelvic_radius', 'degree_spondylolisthesis',
#        'pelvic_slope', 'direct_tilt', 'thoracic_slope', 'cervical_tilt',
#        'sacrum_angle', 'scoliosis_slope', 'class'],
#       dtype='object')

# %%
df3.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 0      98.672917                 -0.254400      0.744503      12.5661
# 1     114.405425                  4.564259      0.415186      12.8874
# 2     105.985135                 -3.530317      0.474889      26.8343
# 3     101.868495                 11.211523      0.369345      23.5603
# 4     108.168725                  7.918501      0.543360      35.4940
#
#    thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope     class
# ...

# %% [markdown]
#     df3.describe()

# %%
df3.describe()
# Out:
#        pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# count        310.000000   310.000000             310.000000    310.000000
# mean          60.496653    17.542822              51.930930     42.953831
# std           17.236520    10.008330              18.554064     13.423102
# min           26.147921    -6.554948              14.000000     13.366931
# 25%           46.430294    10.667069              37.000000     33.347122
# 50%           58.691038    16.357689              49.562398     42.404912
# 75%           72.877696    22.120395              63.000000     52.695888
# max          129.834041    49.431864             125.742385    121.429566
#
#        pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# count     310.000000                310.000000    310.000000   310.000000
# mean      117.920655                 26.296694      0.472979    21.321526
# std        13.317377                 37.559027      0.285787     8.639423
# ...

# %%
df.describe(include = "all")
# Out:
#        Petrol_tax  Average_income  Paved_Highways  \
# count   48.000000       48.000000       48.000000
# mean     7.668333     4241.833333     5565.416667
# std      0.950770      573.623768     3491.507166
# min      5.000000     3063.000000      431.000000
# 25%      7.000000     3739.000000     3110.250000
# 50%      7.500000     4298.000000     4735.500000
# 75%      8.125000     4578.750000     7156.000000
# max     10.000000     5342.000000    17782.000000
#
#        Population_Driver_licence(%)  Petrol_Consumption
# count                     48.000000           48.000000
# mean                       0.570333          576.770833
# std                        0.055470          111.885816
# min                        0.451000          344.000000
# 25%                        0.529750          509.500000
# 50%                        0.564500          568.500000
# 75%                        0.595250          632.750000
# max                        0.724000          968.000000

# %%
df3.describe(include = "all")
# Out:
#         pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# count         310.000000   310.000000             310.000000    310.000000
# unique               NaN          NaN                    NaN           NaN
# top                  NaN          NaN                    NaN           NaN
# freq                 NaN          NaN                    NaN           NaN
# mean           60.496653    17.542822              51.930930     42.953831
# std            17.236520    10.008330              18.554064     13.423102
# min            26.147921    -6.554948              14.000000     13.366931
# 25%            46.430294    10.667069              37.000000     33.347122
# 50%            58.691038    16.357689              49.562398     42.404912
# 75%            72.877696    22.120395              63.000000     52.695888
# max           129.834041    49.431864             125.742385    121.429566
#
# ...

# %%
df3['class'].value_counts()
# Out:
# Abnormal    210
# Normal      100
# Name: class, dtype: int64

# %%
df3["Record_id"] = range(1, len(df3)+1)

# %%
df3.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 0      98.672917                 -0.254400      0.744503      12.5661
# 1     114.405425                  4.564259      0.415186      12.8874
# 2     105.985135                 -3.530317      0.474889      26.8343
# 3     101.868495                 11.211523      0.369345      23.5603
# 4     108.168725                  7.918501      0.543360      35.4940
#
#    thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope     class  \
# ...

# %%
import numpy as np

# %%
df3.iloc[0:5, -1] = np.NaN

# %%
df3.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 0      98.672917                 -0.254400      0.744503      12.5661
# 1     114.405425                  4.564259      0.415186      12.8874
# 2     105.985135                 -3.530317      0.474889      26.8343
# 3     101.868495                 11.211523      0.369345      23.5603
# 4     108.168725                  7.918501      0.543360      35.4940
#
#    thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope     class  \
# ...

# %%
df3.Record_id.isna()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 305    False
# 306    False
# 307    False
# 308    False
# 309    False
# Name: Record_id, Length: 310, dtype: bool

# %%
df3.Record_id.isna().sum()
# Out:
# 5

# %%
df3.dropna()
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 5           40.250200    13.921907              25.124950     26.328293
# 6           53.432928    15.864336              37.165934     37.568592
# 7           45.366754    10.755611              29.038349     34.611142
# 8           43.790190    13.533753              42.690814     30.256437
# 9           36.686353     5.010884              41.948751     31.675469
# ..                ...          ...                    ...           ...
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 307         61.446597    22.694968              46.170347     38.751628
# 308         45.252792     8.693157              41.583126     36.559635
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# ...

# %%
df3.Record_id.sum()
# Out:
# 48190.0

# %%
df3.Record_id.isna().value_counts()
# Out:
# False    305
# True       5
# Name: Record_id, dtype: int64

# %%
df3.Record_id.is_unique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-a55248570315> in <module>
# ----> 1 df3.Record_id.is_unique()
#
# TypeError: 'bool' object is not callable

# %%
df4 = df3.dropna()

# %%
df4.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 5         40.250200    13.921907              25.124950     26.328293
# 6         53.432928    15.864336              37.165934     37.568592
# 7         45.366754    10.755611              29.038349     34.611142
# 8         43.790190    13.533753              42.690814     30.256437
# 9         36.686353     5.010884              41.948751     31.675469
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 5     130.327871                  2.230652      0.789993      29.3230
# 6     120.567523                  5.988551      0.198920      13.8514
# 7     117.270068                -10.675871      0.131973      28.8165
# 8     125.002893                 13.289018      0.190408      22.7085
# 9      84.241415                  0.664437      0.367700      26.2011
#
#    thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope     class  \
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 305 entries, 5 to 309
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          305 non-null    float64
#  1   pelvic_tilt               305 non-null    float64
#  2   lumbar_lordosis_angle     305 non-null    float64
#  3   sacral_slope              305 non-null    float64
#  4   pelvic_radius             305 non-null    float64
#  5   degree_spondylolisthesis  305 non-null    float64
#  6   pelvic_slope              305 non-null    float64
#  7   direct_tilt               305 non-null    float64
#  8   thoracic_slope            305 non-null    float64
#  9   cervical_tilt             305 non-null    float64
#  10  sacrum_angle              305 non-null    float64
#  11  scoliosis_slope           305 non-null    float64
#  12  class                     305 non-null    object
# ...

# %%
df4.isna().sum()
# Out:
# pelvic_incidence            0
# pelvic_tilt                 0
# lumbar_lordosis_angle       0
# sacral_slope                0
# pelvic_radius               0
# degree_spondylolisthesis    0
# pelvic_slope                0
# direct_tilt                 0
# thoracic_slope              0
# cervical_tilt               0
# sacrum_angle                0
# scoliosis_slope             0
# class                       0
# Record_id                   0
# dtype: int64

# %%
df4.to_csv("New_Spine_Data.csv")

# %%
df4.Record_id = df4.Record_id.astype(int)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:5303: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 305 entries, 5 to 309
# Data columns (total 14 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   pelvic_incidence          305 non-null    float64
#  1   pelvic_tilt               305 non-null    float64
#  2   lumbar_lordosis_angle     305 non-null    float64
#  3   sacral_slope              305 non-null    float64
#  4   pelvic_radius             305 non-null    float64
#  5   degree_spondylolisthesis  305 non-null    float64
#  6   pelvic_slope              305 non-null    float64
#  7   direct_tilt               305 non-null    float64
#  8   thoracic_slope            305 non-null    float64
#  9   cervical_tilt             305 non-null    float64
#  10  sacrum_angle              305 non-null    float64
#  11  scoliosis_slope           305 non-null    float64
#  12  class                     305 non-null    object
# ...

# %%
#df3.loc[conditon for rows, condition for columns]

# %%
df3.loc[df3.pelvic_incidence >65]
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 2           68.832021    22.218482              50.092194     46.613539
# 3           69.297008    24.652878              44.311238     44.644130
# 29          66.879211    24.891999              49.278597     41.987212
# 43          66.285394    26.327845              47.500000     39.957549
# 51          74.433593    41.557331              27.700000     32.876262
# ..                ...          ...                    ...           ...
# 285         67.804694    16.550662              43.256802     51.254033
# 288         74.565015    15.724320              58.618582     58.840695
# 298         66.507179    20.897672              31.727471     45.609507
# 299         82.905351    29.894119              58.250542     53.011232
# 301         89.014875    26.075981              69.021259     62.938894
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# ...

# %%
df3.loc[df3.pelvic_incidence > 65, "Record_id"]
# Out:
# 2        NaN
# 3        NaN
# 29      30.0
# 43      44.0
# 51      52.0
#        ...
# 285    286.0
# 288    289.0
# 298    299.0
# 299    300.0
# 301    302.0
# Name: Record_id, Length: 121, dtype: float64

# %%
df3.loc[df3.pelvic_incidence > 65, ["Record_id", "pelvic_incidence"]]
# Out:
#      Record_id  pelvic_incidence
# 2          NaN         68.832021
# 3          NaN         69.297008
# 29        30.0         66.879211
# 43        44.0         66.285394
# 51        52.0         74.433593
# ..         ...               ...
# 285      286.0         67.804694
# 288      289.0         74.565015
# 298      299.0         66.507179
# 299      300.0         82.905351
# 301      302.0         89.014875
#
# [121 rows x 2 columns]

# %%
df3.loc[(df3.pelvic_incidence > 65) & (df3["class"] == "Normal"), ["Record_id", "pelvic_incidence", "class"]]
# Out:
#      Record_id  pelvic_incidence   class
# 223      224.0         69.398818  Normal
# 224      225.0         89.834676  Normal
# 230      231.0         65.611802  Normal
# 238      239.0         69.004913  Normal
# 254      255.0         72.955644  Normal
# 255      256.0         67.538182  Normal
# 261      262.0         74.976021  Normal
# 275      276.0         67.289712  Normal
# 277      278.0         65.756348  Normal
# 285      286.0         67.804694  Normal
# 288      289.0         74.565015  Normal
# 298      299.0         66.507179  Normal
# 299      300.0         82.905351  Normal
# 301      302.0         89.014875  Normal

# %%
df3.loc[(df3.sacral_slope > 25) & (df3.sacral_slope < 35)].tail(10)
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 287         33.041688    -0.324678              19.071075     33.366366
# 289         44.430701    14.174264              32.243495     30.256437
# 292         34.756738     2.631740              29.504381     32.124998
# 297         45.575482    18.759135              33.774143     26.816347
# 302         54.600316    21.488974              29.360216     33.111342
# 303         34.382299     2.062683              32.390820     32.319617
# 304         45.075450    12.306951              44.583177     32.768499
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 287     120.388611                  9.354365      0.167309      17.1960
# ...

# %%
df3.loc[(df3.sacral_slope > 25) & (df3.sacral_slope < 35)]
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 1           39.056951    10.060991              25.015378     28.995960
# 5           40.250200    13.921907              25.124950     26.328293
# 7           45.366754    10.755611              29.038349     34.611142
# 8           43.790190    13.533753              42.690814     30.256437
# 9           36.686353     5.010884              41.948751     31.675469
# ..                ...          ...                    ...           ...
# 303         34.382299     2.062683              32.390820     32.319617
# 304         45.075450    12.306951              44.583177     32.768499
# 305         47.903565    13.616688              36.000000     34.286877
# 306         53.936748    20.721496              29.220534     33.215251
# 309         33.841641     5.073991              36.641233     28.767649
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# ...

# %%
df3.loc[df3.pelvic_incidence > 100]
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 115        129.834041     8.404475              48.384057    121.429566
# 162        118.144655    38.449501              50.838520     79.695154
# 163        115.923261    37.515436              76.800000     78.407825
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 115     107.690466                418.543082      0.860223      18.5943
# 162      81.024541                 74.043767      0.599393      35.8563
# 163     104.698603                 81.198927      0.542816      22.3317
#
#      thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope     class  \
# 115         11.1514       11.36543    -34.202073          27.5144  Abnormal
# 162         10.9266       13.11354    -17.520810          21.2408  Abnormal
# 163          8.8519       11.48960     -6.754004          32.5082  Abnormal
#
#      Record_id
# 115      116.0
# 162      163.0
# 163      164.0

# %%
df3.loc[df3.pelvic_incidence > 100, "pelvic_incidence"] = 100

# %%
df3.loc[df3.pelvic_incidence > 99]
# Out:
#      pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 115             100.0     8.404475              48.384057    121.429566
# 162             100.0    38.449501              50.838520     79.695154
# 163             100.0    37.515436              76.800000     78.407825
#
#      pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 115     107.690466                418.543082      0.860223      18.5943
# 162      81.024541                 74.043767      0.599393      35.8563
# 163     104.698603                 81.198927      0.542816      22.3317
#
#      thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope     class  \
# 115         11.1514       11.36543    -34.202073          27.5144  Abnormal
# 162         10.9266       13.11354    -17.520810          21.2408  Abnormal
# 163          8.8519       11.48960     -6.754004          32.5082  Abnormal
#
#      Record_id  pelvic_incidence=100
# 115      116.0                 100.0
# ...

# %%
df3.iloc[5]
# Out:
# pelvic_incidence             40.2502
# pelvic_tilt                  13.9219
# lumbar_lordosis_angle        25.1249
# sacral_slope                 26.3283
# pelvic_radius                130.328
# degree_spondylolisthesis     2.23065
# pelvic_slope                0.789993
# direct_tilt                   29.323
# thoracic_slope               12.0036
# cervical_tilt                10.4046
# sacrum_angle                -1.51221
# scoliosis_slope               9.6548
# class                       Abnormal
# Record_id                          6
# pelvic_incidence=100             NaN
# Name: 5, dtype: object

# %%
df3.head()
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 0      98.672917                 -0.254400      0.744503      12.5661
# 1     114.405425                  4.564259      0.415186      12.8874
# 2     105.985135                 -3.530317      0.474889      26.8343
# 3     101.868495                 11.211523      0.369345      23.5603
# 4     108.168725                  7.918501      0.543360      35.4940
#
#    thoracic_slope  cervical_tilt  sacrum_angle  scoliosis_slope     class  \
# ...

# %%
df3.head(10)
# Out:
#    pelvic_incidence  pelvic_tilt  lumbar_lordosis_angle  sacral_slope  \
# 0         63.027818    22.552586              39.609117     40.475232
# 1         39.056951    10.060991              25.015378     28.995960
# 2         68.832021    22.218482              50.092194     46.613539
# 3         69.297008    24.652878              44.311238     44.644130
# 4         49.712859     9.652075              28.317406     40.060784
# 5         40.250200    13.921907              25.124950     26.328293
# 6         53.432928    15.864336              37.165934     37.568592
# 7         45.366754    10.755611              29.038349     34.611142
# 8         43.790190    13.533753              42.690814     30.256437
# 9         36.686353     5.010884              41.948751     31.675469
#
#    pelvic_radius  degree_spondylolisthesis  pelvic_slope  direct_tilt  \
# 0      98.672917                 -0.254400      0.744503      12.5661
# ...

# %%
df3.iloc[:5, 1]
# Out:
# 0    22.552586
# 1    10.060991
# 2    22.218482
# 3    24.652878
# 4     9.652075
# Name: pelvic_tilt, dtype: float64

# %%
df3.iloc[:5, 0]
# Out:
# 0    63.027818
# 1    39.056951
# 2    68.832021
# 3    69.297008
# 4    49.712859
# Name: pelvic_incidence, dtype: float64

# %%
df3.iloc[:5, [0,4,1,3,5,4]]
# Out:
#    pelvic_incidence  pelvic_radius  pelvic_tilt  sacral_slope  \
# 0         63.027818      98.672917    22.552586     40.475232
# 1         39.056951     114.405425    10.060991     28.995960
# 2         68.832021     105.985135    22.218482     46.613539
# 3         69.297008     101.868495    24.652878     44.644130
# 4         49.712859     108.168725     9.652075     40.060784
#
#    degree_spondylolisthesis  pelvic_radius
# 0                 -0.254400      98.672917
# 1                  4.564259     114.405425
# 2                 -3.530317     105.985135
# 3                 11.211523     101.868495
# 4                  7.918501     108.168725
