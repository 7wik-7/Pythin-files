# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import sklearn

# %%
data = pd.read_csv("house_price.csv")

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
data.shape
# Out:
# (1460, 81)

# %%
data.describe()
# Out:
#                 Id   MSSubClass  ...       YrSold      SalePrice
# count  1460.000000  1460.000000  ...  1460.000000    1460.000000
# mean    730.500000    56.897260  ...  2007.815753  180921.195890
# std     421.610009    42.300571  ...     1.328095   79442.502883
# min       1.000000    20.000000  ...  2006.000000   34900.000000
# 25%     365.750000    20.000000  ...  2007.000000  129975.000000
# 50%     730.500000    50.000000  ...  2008.000000  163000.000000
# 75%    1095.250000    70.000000  ...  2009.000000  214000.000000
# max    1460.000000   190.000000  ...  2010.000000  755000.000000
#
# [8 rows x 38 columns]

# %%
data.isna().sum().sort_values()
# Out:
# Id                  0
# TotalBsmtSF         0
# Heating             0
# SaleCondition       0
# CentralAir          0
#                  ...
# FireplaceQu       690
# Fence            1179
# Alley            1369
# MiscFeature      1406
# PoolQC           1453
# Length: 81, dtype: int64

# %%
# Fill Rate -> How much values do you have out of total rows ? 
# fill_rate = 1 - na_rate

# %%
na_rate = data.isna().mean().sort_values()
na_rate
# Out:
# Id               0.000000
# TotalBsmtSF      0.000000
# Heating          0.000000
# SaleCondition    0.000000
# CentralAir       0.000000
#                    ...
# FireplaceQu      0.472603
# Fence            0.807534
# Alley            0.937671
# MiscFeature      0.963014
# PoolQC           0.995205
# Length: 81, dtype: float64

# %%
na_rate[na_rate > 0.8].index.tolist()
# Out:
# ['Fence', 'Alley', 'MiscFeature', 'PoolQC']

# %%
df1 = data.drop(columns=na_rate[na_rate > 0.8].index.tolist())

# %%
df1.shape
# Out:
# (1460, 77)

# %%
df1.isna().sum().sort_values()
# Out:
# Id                 0
# TotalBsmtSF        0
# SaleCondition      0
# HeatingQC          0
# CentralAir         0
#                 ...
# GarageFinish      81
# GarageType        81
# GarageYrBlt       81
# LotFrontage      259
# FireplaceQu      690
# Length: 77, dtype: int64

# %%
plt.figure(figsize=(10,10))
data.isna().mean().sort_values().plot.barh()
plt.plot()
# Out:
# []

# %%
df1.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 77 columns]

# %%
# Drop ID

# %%
df1 = df1.drop(columns=["Id"])

# %%
df1.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# 0          60       RL         65.0  ...        WD        Normal    208500
# 1          20       RL         80.0  ...        WD        Normal    181500
# 2          60       RL         68.0  ...        WD        Normal    223500
# 3          70       RL         60.0  ...        WD       Abnorml    140000
# 4          60       RL         84.0  ...        WD        Normal    250000
#
# [5 rows x 76 columns]

# %%
df1.YearBuilt
# Out:
# 0       2003
# 1       1976
# 2       2001
# 3       1915
# 4       2000
#         ...
# 1455    1999
# 1456    1978
# 1457    1941
# 1458    1950
# 1459    1965
# Name: YearBuilt, Length: 1460, dtype: int64

# %%
# We dont want YEAR in our data so we calculate the age of house & we will use Year Remodelling 
df1["AgeOfHouse"] = 2020 - df1.YearRemodAdd  # please use 2020 as dynamic datatime.datetime.now().year

# %%
df1 = df1.drop(columns=["YearBuilt", "YearRemodAdd"])

# %%
df1.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  ...  SaleCondition SalePrice AgeOfHouse
# 0          60       RL         65.0  ...         Normal    208500         17
# 1          20       RL         80.0  ...         Normal    181500         44
# 2          60       RL         68.0  ...         Normal    223500         18
# 3          70       RL         60.0  ...        Abnorml    140000         50
# 4          60       RL         84.0  ...         Normal    250000         20
#
# [5 rows x 75 columns]

# %%
df1.SalePrice
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
sns.distplot(df1.SalePrice)
plt.plot()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# []

# %%
df1[["SalePrice"]].boxplot()

# %%
f_q = np.percentile(df1.SalePrice, 25)
l_q = np.percentile(df1.SalePrice, 75)

IQR = 1.5*(l_q - f_q)

# %%
ideal_max = l_q + IQR
ideal_min = f_q - IQR
ideal_max, ideal_min
# Out:
# (340037.5, 3937.5)

# %%
df1.loc[df1.SalePrice > ideal_max]
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  SaleCondition SalePrice AgeOfHouse
# 11            60       RL         85.0  ...        Partial    345000         14
# 53            20       RL         68.0  ...         Normal    385000         33
# 58            60       RL         66.0  ...        Partial    438780         14
# 112           60       RL         77.0  ...        Partial    383970         13
# 151           20       RL        107.0  ...        Partial    372402         12
# ...          ...      ...          ...  ...            ...       ...        ...
# 1268          50       RL          NaN  ...         Normal    381000         23
# 1353          50       RL         56.0  ...         Normal    410000         24
# 1373          20       RL          NaN  ...         Normal    466500         18
# 1388          20       RL         42.0  ...         Normal    377500         13
# 1437          20       RL         96.0  ...        Partial    394617         12
#
# ...

# %%
df1.loc[df1.SalePrice > 500000]
# Out:
#       MSSubClass MSZoning  LotFrontage  ...  SaleCondition SalePrice AgeOfHouse
# 178           20       RL         63.0  ...        Partial    501837         11
# 440           20       RL        105.0  ...         Normal    555000         12
# 691           60       RL        104.0  ...         Normal    755000         25
# 769           60       RL         47.0  ...         Normal    538000         17
# 803           60       RL        107.0  ...        Partial    582933         11
# 898           20       RL        100.0  ...        Partial    611657         10
# 1046          60       RL         85.0  ...        Partial    556581         14
# 1169          60       RL        118.0  ...         Normal    625000         24
# 1182          60       RL        160.0  ...        Abnorml    745000         24
#
# [9 rows x 75 columns]

# %%
# You can consult and remove the anomaly lines in SalePrice # We are not removing them ....

# %%
df1.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# AgeOfHouse         int64
# Length: 75, dtype: object

# %%
# Check for every column that it has correct dtype - otherwise change it
df1.MSSubClass = df1.MSSubClass.astype("object")

# %%
df1.dtypes
# Out:
# MSSubClass        object
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# AgeOfHouse         int64
# Length: 75, dtype: object

# %%
set(df1.dtypes.tolist())
# Out:
# {dtype('int64'), dtype('float64'), dtype('O')}

# %%
df_num = df1.select_dtypes(include=["float64", "int64"])

# %%
df_num.head()
# Out:
#    LotFrontage  LotArea  OverallQual  ...  YrSold  SalePrice  AgeOfHouse
# 0         65.0     8450            7  ...    2008     208500          17
# 1         80.0     9600            6  ...    2007     181500          44
# 2         68.0    11250            7  ...    2008     223500          18
# 3         60.0     9550            7  ...    2006     140000          50
# 4         84.0    14260            8  ...    2008     250000          20
#
# [5 rows x 35 columns]

# %%
df_num.dtypes
# Out:
# LotFrontage      float64
# LotArea            int64
# OverallQual        int64
# OverallCond        int64
# MasVnrArea       float64
# BsmtFinSF1         int64
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# TotalBsmtSF        int64
# 1stFlrSF           int64
# 2ndFlrSF           int64
# LowQualFinSF       int64
# GrLivArea          int64
# BsmtFullBath       int64
# BsmtHalfBath       int64
# FullBath           int64
# HalfBath           int64
# BedroomAbvGr       int64
# KitchenAbvGr       int64
# TotRmsAbvGrd       int64
# Fireplaces         int64
# GarageYrBlt      float64
# GarageCars         int64
# GarageArea         int64
# WoodDeckSF         int64
# OpenPorchSF        int64
# EnclosedPorch      int64
# 3SsnPorch          int64
# ScreenPorch        int64
# PoolArea           int64
# MiscVal            int64
# MoSold             int64
# YrSold             int64
# SalePrice          int64
# AgeOfHouse         int64
# dtype: object

# %%
df_num.hist(figsize=(16, 20))
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10, 10))
sns.heatmap(df_num.corr(), cmap="Greens", annot=True)
plt.plot()
# Out:
# []

# %%
num_corr = abs(df_num.corr()["SalePrice"]).sort_values()
num_corr
# Out:
# BsmtFinSF2       0.011378
# BsmtHalfBath     0.016844
# MiscVal          0.021190
# LowQualFinSF     0.025606
# YrSold           0.028923
# 3SsnPorch        0.044584
# MoSold           0.046432
# OverallCond      0.077856
# PoolArea         0.092404
# ScreenPorch      0.111447
# EnclosedPorch    0.128578
# KitchenAbvGr     0.135907
# BedroomAbvGr     0.168213
# BsmtUnfSF        0.214479
# BsmtFullBath     0.227122
# LotArea          0.263843
# HalfBath         0.284108
# OpenPorchSF      0.315856
# 2ndFlrSF         0.319334
# WoodDeckSF       0.324413
# LotFrontage      0.351799
# BsmtFinSF1       0.386420
# Fireplaces       0.466929
# MasVnrArea       0.477493
# GarageYrBlt      0.486362
# AgeOfHouse       0.507101
# TotRmsAbvGrd     0.533723
# FullBath         0.560664
# 1stFlrSF         0.605852
# TotalBsmtSF      0.613581
# GarageArea       0.623431
# GarageCars       0.640409
# GrLivArea        0.708624
# OverallQual      0.790982
# SalePrice        1.000000
# ...

# %%
num_corr[num_corr > 0.5]
# Out:
# AgeOfHouse      0.507101
# TotRmsAbvGrd    0.533723
# FullBath        0.560664
# 1stFlrSF        0.605852
# TotalBsmtSF     0.613581
# GarageArea      0.623431
# GarageCars      0.640409
# GrLivArea       0.708624
# OverallQual     0.790982
# SalePrice       1.000000
# Name: SalePrice, dtype: float64

# %%
golden_num_feature = num_corr[num_corr > 0.5].index.tolist()

# %%
sns.pairplot(df_num, x_vars=golden_num_feature, y_vars=["SalePrice"])

# %%
sns.heatmap(df_num.loc[:, golden_num_feature].corr(), cmap="Greens", annot=True)

# %%
sns.scatterplot(x="AgeOfHouse", y="SalePrice", data=df_num)

# %%
df_cat = df1.select_dtypes("object")

# %%
df_cat
# Out:
#      MSSubClass MSZoning Street  ... PavedDrive SaleType SaleCondition
# 0            60       RL   Pave  ...          Y       WD        Normal
# 1            20       RL   Pave  ...          Y       WD        Normal
# 2            60       RL   Pave  ...          Y       WD        Normal
# 3            70       RL   Pave  ...          Y       WD       Abnorml
# 4            60       RL   Pave  ...          Y       WD        Normal
# ...         ...      ...    ...  ...        ...      ...           ...
# 1455         60       RL   Pave  ...          Y       WD        Normal
# 1456         20       RL   Pave  ...          Y       WD        Normal
# 1457         70       RL   Pave  ...          Y       WD        Normal
# 1458         20       RL   Pave  ...          Y       WD        Normal
# 1459         20       RL   Pave  ...          Y       WD        Normal
#
# [1460 rows x 40 columns]

# %%
df_cat["SalePrice"] = df1.SalePrice
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.violinplot(x="SalePrice", y="Electrical", data=df_cat)
plt.xticks(rotation=45)
plt.plot()
# Out:
# []

# %%
sns.violinplot(x="SalePrice", y="GarageType", data=df_cat)
plt.xticks(rotation=45)
plt.plot()
# Out:
# []

# %%
sns.violinplot(x="SalePrice", y="MSZoning", data=df_cat)
plt.xticks(rotation=45)
plt.plot()
# Out:
# []

# %%
len(df_cat.columns)
# Out:
# 41

# %%
for i in range(1, len(df_cat.columns), 5):
  for j in range(1, i):
    sns.violinplot(x="SalePrice", y=df_cat.columns[i+j], data=df_cat)
    plt.xticks(rotation=45)
  break

# %%
for i in range(1, len(df_cat.columns)):
  plt.subplot(8, 5, i)
  sns.violinplot(x="SalePrice", y=df_cat.columns[i], data=df_cat)
  plt.xticks(rotation=45)
  plt.plot()

# %%
# Mapping of column
df_cat.MSSubClass.value_counts()
# Out:
# 20     536
# 60     299
# 50     144
# 120     87
# 30      69
# 160     63
# 70      60
# 80      58
# 90      52
# 190     30
# 85      20
# 75      16
# 45      12
# 180     10
# 40       4
# Name: MSSubClass, dtype: int64

# %%
mssubclass_dict= {
        20:	"1-STORY 1946",
        30:	"1-STORY 1946",
        40:	"1-STORY W/FINISHED ATTIC ALL AGES",
        45:	"1-1/2 STORY - UNFINISHED ALL AGES",
        50:	"1-1/2 STORY FINISHED ALL AGES",
        60:	"2-STORY 1946 & NEWER",
        70:	"2-STORY 1945 & OLDER",
        75:	"2-1/2 STORY ALL AGES",
        80:	"SPLIT OR MULTI-LEVEL",
        85:	"SPLIT FOYER",
        90:	"DUPLEX - ALL STYLES AND AGES",
       120:	"1-STORY PUD (Planned Unit Development) - 1946 & NEWER",
       150:	"1-1/2 STORY PUD - ALL AGES",
       160:	"2-STORY PUD - 1946 & NEWER",
       180:	"PUD - MULTILEVEL - INCL SPLIT LEV/FOYER",
       190:	"2 FAMILY CONVERSION - ALL STYLES AND AGES"}

# %%
mssubclass_dict
# Out:
# {20: '1-STORY 1946',
#  30: '1-STORY 1946',
#  40: '1-STORY W/FINISHED ATTIC ALL AGES',
#  45: '1-1/2 STORY - UNFINISHED ALL AGES',
#  50: '1-1/2 STORY FINISHED ALL AGES',
#  60: '2-STORY 1946 & NEWER',
#  70: '2-STORY 1945 & OLDER',
#  75: '2-1/2 STORY ALL AGES',
#  80: 'SPLIT OR MULTI-LEVEL',
#  85: 'SPLIT FOYER',
#  90: 'DUPLEX - ALL STYLES AND AGES',
#  120: '1-STORY PUD (Planned Unit Development) - 1946 & NEWER',
#  150: '1-1/2 STORY PUD - ALL AGES',
#  160: '2-STORY PUD - 1946 & NEWER',
#  180: 'PUD - MULTILEVEL - INCL SPLIT LEV/FOYER',
#  190: '2 FAMILY CONVERSION - ALL STYLES AND AGES'}

# %%
df_cat["MSSubClass_obj"] = df_cat.MSSubClass.map(mssubclass_dict)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.violinplot(x="SalePrice", y="MSSubClass_obj", data=df_cat)
plt.xticks(rotation=45)
plt.plot()
# Out:
# []
